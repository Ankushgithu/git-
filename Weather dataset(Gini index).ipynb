# %% [markdown]
# # Gini

# %% [markdown]
# # 1.Outlook

# %%
import numpy as np

# %%
(outlook = overcast) >> 4Y and 0N  >>  (4/14)
(outlook = rainy) >> 3Y and 2N     >> (5/14)
(outlook = sunny) >> 2Y and 3N     >> (5/14)
Total values >> 9Y and 5N
G(outlook = overcast) = 0
G(outlook = rainy) = 0.48
G(outlook = sunny) = 0.48

Gini_Outlook = sum(weighted_avg*GI of each value)

 GI = 1-[p(Y)^2 + P(N)^2]

# %%
#(outlook = overcast) 
1 - ((1)**2 +0)
# Out:
# 0

# %%
# Outlook = rainy
1 - ((3/5)**2 + (2/5)**2)
# Out:
# 0.48

# %%
1 - ((2/5)**2 + (3/5)**2)
# Out:
# 0.48

# %%
GI_index_Outlook = (0 + (5/14)*0.48 + (5/14)*0.48)
GI_index_Outlook
# Out:
# 0.34285714285714286

# %% [markdown]
# # 2.temperature

# %%
(temperature = hot) >> 2Y and 2N  >>  (4/14)
(temperature = cool) >> 3Y and 1N     >> (4/14)
(temperature = mild) >> 4Y and 2N     >> (6/14)
Total values >> 9Y and 5N
G(temperature = hot) = 0.5
G(temperature = cool) = 0.375
G(temperature = mild) = 0.4444444444444444

# %%
1 - ((0.5)**2+(0.5)**2)
# Out:
# 0.5

# %%
1 - ((3/4)**2+(1/4)**2)
# Out:
# 0.375

# %%
1 - ((4/6)**2+(2/6)**2)
# Out:
# 0.4444444444444444

# %%
GI_temperature = ((4/14)*0.5 + (4/14)*0.375 + (6/14)*0.444444)
GI_temperature
# Out:
# 0.440476

# %% [markdown]
# # 3.humidity

# %%
(humidity = high) >> 3Y and 4N  >>  (7/14)
(humidity = normal) >> 6Y and 1N     >> (7/14)

Total values >> 9Y and 5N
G(humidity = high) = 0.489
G(humidity = normal) = 0.2448

# %%
1 - ((3/7)**2+(4/7)**2)
# Out:
# 0.48979591836734704

# %%
1 - ((6/7)**2+(1/7)**2)
# Out:
# 0.24489795918367352

# %%
GI_humidity = ((7/14)*0.4897 + (7/14)*0.2448)
GI_humidity
# Out:
# 0.36725

# %% [markdown]
# # 4. Windy

# %%
(windy = True) >> 3Y and 3N  >>  (6/14)
(Windy = False) >> 6Y and 2N     >> (8/14)

Total values >> 9Y and 5N
G(windy = True) = 0.5
G(Windy = False) = 0.97

# %%
1 - ((3/6)**2+(3/6)**2)
# Out:
# 0.5

# %%
1 - ((6/8)**2+(2/8)**2)
# Out:
# 0.375

# %%
GI_windy = ((6/14)*0.5 + (8/14)*0.375)
GI_windy
# Out:
# 0.42857142857142855

# %%
print('GI_Outlook >>',GI_Outlook)
print('GI_temperature >>',GI_temperature)
print('GI_humidity >>',GI_humidity)
print('GI_windy >>',GI_windy)
# Out:
# GI_Outlook >> 0.34285714285714286
# GI_temperature >> 0.440476
# GI_humidity >> 0.36725
# GI_windy >> 0.42857142857142855

# %%
outlook >> temperature  >> humidity  >> windy
 rainy       mild           normal     False  >>  Yes

# %% [markdown]
# ![image.png](attachment:image.png)
